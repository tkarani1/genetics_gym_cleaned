# %%
import hail as hl
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a987c675-0381-44e6-8a3c-9c9a9105195a">Loading BokehJS ...</span>
#     </div>

# %%
hl.init()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# SPARKMONITOR_LISTENER: Started SparkListener for Jupyter Notebook
# SPARKMONITOR_LISTENER: Port obtained from environment: 36277
# SPARKMONITOR_LISTENER: Application Started: application_1745606131714_0004 ...Start Time: 1745618562544
# Running on Apache Spark version 3.5.0
# SparkUI available at http://tk-m.c.nnf-karczewski.internal:37943
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.133-4c60fddb171a
# LOGGING: writing to /home/hail/hail-20250425-2202-0.2.133-4c60fddb171a.log

# %%
linker_ens = hl.read_table('gs://genetics-gym-not-public/Trisha/linker_ens_iso_all_mapped.ht')

# %%
linker_ens.show()
# Out:
# +---------------+------------+--------+--------+--------+-------------+
# | locus         | alleles    | aa_pos | aa_ref | aa_alt | gene_symbol |
# +---------------+------------+--------+--------+--------+-------------+
# | locus<GRCh38> | array<str> |  int32 | str    | str    | str         |
# +---------------+------------+--------+--------+--------+-------------+
# | chr1:65568    | ["A","C"]  |      2 | "K"    | "Q"    | "OR4F5"     |
# | chr1:65568    | ["A","G"]  |      2 | "K"    | "E"    | "OR4F5"     |
# | chr1:65569    | ["A","C"]  |      2 | "K"    | "T"    | "OR4F5"     |
# | chr1:65569    | ["A","G"]  |      2 | "K"    | "R"    | "OR4F5"     |
# | chr1:65569    | ["A","T"]  |      2 | "K"    | "M"    | "OR4F5"     |
# | chr1:65570    | ["G","C"]  |      2 | "K"    | "N"    | "OR4F5"     |
# | chr1:65570    | ["G","T"]  |      2 | "K"    | "N"    | "OR4F5"     |
# | chr1:65571    | ["A","C"]  |      3 | "K"    | "Q"    | "OR4F5"     |
# ...

# %%
linker_rs = hl.read_table('gs://genetics-gym-not-public/Trisha/linker_alt_refseq_iso_all_mapped.ht')

# %%
linker_rs.show()
# Out:
# +---------------+------------+--------+--------+--------+-------------+
# | locus         | alleles    | aa_pos | aa_ref | aa_alt | gene_symbol |
# +---------------+------------+--------+--------+--------+-------------+
# | locus<GRCh38> | array<str> |  int32 | str    | str    | str         |
# +---------------+------------+--------+--------+--------+-------------+
# | chr1:65568    | ["A","C"]  |      2 | "K"    | "Q"    | "OR4F5"     |
# | chr1:65568    | ["A","G"]  |      2 | "K"    | "E"    | "OR4F5"     |
# | chr1:65569    | ["A","C"]  |      2 | "K"    | "T"    | "OR4F5"     |
# | chr1:65569    | ["A","G"]  |      2 | "K"    | "R"    | "OR4F5"     |
# | chr1:65569    | ["A","T"]  |      2 | "K"    | "M"    | "OR4F5"     |
# | chr1:65570    | ["G","C"]  |      2 | "K"    | "N"    | "OR4F5"     |
# | chr1:65570    | ["G","T"]  |      2 | "K"    | "N"    | "OR4F5"     |
# | chr1:65571    | ["A","C"]  |      3 | "K"    | "Q"    | "OR4F5"     |
# ...

# %% [markdown]
# # VSM tables

# %%
higher_is_less_deleterious = {
    'esm_score':True,
    'proteinmpnn_llr':True,
    'am_pathogenicity':False,
    'score_PAI3D':False,
    'rasp_score':False,
    'MisFit_S':False,
    'MisFit_D':False,
    'popeve':True,
    'eve':False,
    'esm1_v':True,
    'mpc':False,
}
score_list = list(higher_is_less_deleterious.keys())

# %%
def join_all():
    ht = hl.read_table(final_linker)
    for score_table in score_table_list:
        print(score_table)
        ht_score = hl.read_table(score_table)
        ht = join_tables(ht, ht_score, score_list, filter=False)

    for s in score_list:
        if higher_is_less_deleterious[s]:
            ht = ht.annotate(
                **{f'{s}_neg': 1-ht[s]}
            )

    print('writing file')
    ht.write('gs://genetics-gym-not-public/Trisha/hail_VSM_tables_updated/all_models_scores.ht', True)    # group by locus, alleles # if more than one score, take max (if higher is less deleterious)
    print('done')

# %%
def join_tables(ht_to, ht_from, columns_to_join=None, filter=False, broadcast=False):
    # keys of ht_from must be columns in ht_to
    # columns_to_join are the columns from ht_from to add to ht_to
    if columns_to_join is None:
        columns_to_join = ht_from.row
    columns_to_join = [c for c in columns_to_join if c in ht_from.row and not c in ht_to.row]  
    if broadcast:
        ht_temp = create_broadcast_dict(
            ht_from.select(*columns_to_join)
        ).get(ht_to.row.select(*list(ht_from.key)))
    else:
        ht_temp = ht_from[ht_to.row.select(*list(ht_from.key))]
    ht_joined = ht_to.annotate(**{c: ht_temp[c] for c in columns_to_join})
    if filter:
        ht_joined = ht_joined.filter(hl.all([hl.is_defined(ht_joined[c]) for c in columns_to_join]))
    return ht_joined

# %% [markdown]
# ## ESM1b

# %%
esm1b_ht = hl.import_table(
        'gs://missense-scoring/esm1b-650m-brandes/proc/*.txt.bgz',
        types = {
            'aa_pos':hl.tint,
            'aa_ref':hl.tstr,
            'aa_alt':hl.tstr,
            'esm_score':hl.tfloat,
            'uniprot':hl.tstr,
        },
        force=True,
        missing='',
    )
esm1b_ht = esm1b_ht.rename({'uniprot': 'uniprot_isoform'})
esm1b_ht.write('gs://genetics-gym-not-public/Trisha/updated_data_tables/esm1b_scores.ht', True)
# Out:
# 2025-04-25 13:59:06.529 Hail: INFO: Reading table without type imputation1) / 1]
#   Loading field 'aa_alt' as type str (user-supplied)
#   Loading field 'aa_pos' as type int32 (user-supplied)
#   Loading field 'aa_ref' as type str (user-supplied)
#   Loading field 'esm_score' as type float64 (user-supplied)
#   Loading field 'uniprot' as type str (user-supplied)
# 2025-04-25 14:41:57.527 Hail: INFO: wrote table with 486678080 rows in 42286 partitions to gs://genetics-gym-not-public/Trisha/updated_data_tables/esm1b_scores.ht

# %%
esm1b_ht = hl.read_table('gs://genetics-gym-not-public/Trisha/updated_data_tables/esm1b_scores.ht')
esm1b_ht.show()
# Out:
# +--------+--------+--------+-----------+-----------------+
# | aa_alt | aa_pos | aa_ref | esm_score | uniprot_isoform |
# +--------+--------+--------+-----------+-----------------+
# | str    |  int32 | str    |   float64 | str             |
# +--------+--------+--------+-----------+-----------------+
# | "A"    |      1 | "M"    | -6.09e+00 | "A0A024RBG1"    |
# | "C"    |      1 | "M"    | -7.72e+00 | "A0A024RBG1"    |
# | "D"    |      1 | "M"    | -6.25e+00 | "A0A024RBG1"    |
# | "E"    |      1 | "M"    | -5.44e+00 | "A0A024RBG1"    |
# | "F"    |      1 | "M"    | -6.36e+00 | "A0A024RBG1"    |
# | "G"    |      1 | "M"    | -6.06e+00 | "A0A024RBG1"    |
# | "H"    |      1 | "M"    | -7.20e+00 | "A0A024RBG1"    |
# | "I"    |      1 | "M"    | -6.13e+00 | "A0A024RBG1"    |
# | "K"    |      1 | "M"    | -5.43e+00 | "A0A024RBG1"    |
# | "L"    |      1 | "M"    | -5.43e+00 | "A0A024RBG1"    |
# +--------+--------+--------+-----------+-----------------+
# showing top 10 rows

# %% [markdown]
# ## MisFit

# %%
mf_mapping = hl.import_table('gs://missense-scoring/misfit/raw/geneset_s_gene.txt')
mf_mapping.show()
# Out:
# 2025-04-25 13:16:50.022 Hail: INFO: Reading table without type imputation
#   Loading field 'UniprotID' as type str (not specified)
#   Loading field 'GeneID' as type str (not specified)
#   Loading field 'TranscriptID' as type str (not specified)
#   Loading field 'Symbol' as type str (not specified)
#   Loading field 'ProteinID' as type str (not specified)
#   Loading field 'UniprotEntryName' as type str (not specified)
#   Loading field 'Strand' as type str (not specified)
#   Loading field 'Chrom' as type str (not specified)
#   Loading field 'Length' as type str (not specified)
#   Loading field 'MisFit_sgene_mis' as type str (not specified)
#   Loading field 'MisFit_sgene_ptv' as type str (not specified)
#   Loading field 'logit_s_mean_mis' as type str (not specified)
#   Loading field 'logit_s_sd_mis' as type str (not specified)
#   Loading field 'logit_s_mean_ptv' as type str (not specified)
#   Loading field 'logit_s_sd_ptv' as type str (not specified)
# ...

# %%
mf_one = hl.import_table('gs://missense-scoring/misfit/raw/MisFit_by_Uniprot/A0A024RBG1.txt.gz', force=True)
mf_one.show()
# Out:
# 2025-04-25 13:12:08.777 Hail: INFO: Reading table without type imputation
#   Loading field 'Uniprot_position' as type str (not specified)
#   Loading field 'AA_alt' as type str (not specified)
#   Loading field 'MisFit_D' as type str (not specified)
#   Loading field 'MisFit_S' as type str (not specified)
# +------------------+--------+------------+----------+
# | Uniprot_position | AA_alt | MisFit_D   | MisFit_S |
# +------------------+--------+------------+----------+
# | str              | str    | str        | str      |
# +------------------+--------+------------+----------+
# | "1"              | "A"    | "0.73492"  | ""       |
# | "1"              | "C"    | "0.999563" | ""       |
# | "1"              | "D"    | "0.94592"  | ""       |
# | "1"              | "E"    | "0.812157" | ""       |
# | "1"              | "F"    | "0.709882" | ""       |
# | "1"              | "G"    | "0.726286" | ""       |
# | "1"              | "H"    | "0.983934" | ""       |
# ...

# %%
misfit_ht = hl.import_table(
        'gs://missense-scoring/misfit/raw/MisFit_by_Uniprot/*.txt.gz',
        source_file_field='filename',
        types = {
            'Uniprot_position':hl.tint,
            'AA_alt':hl.tstr,
            'MisFit_D':hl.tfloat,
            'MisFit_S':hl.tfloat,
        },
        force=True,
        missing='',
    )
misfit_ht = misfit_ht.annotate(
    uniprot_id = misfit_ht.filename.split('/')[-1].split('\.')[0],
)
misfit_ht = misfit_ht.rename({'Uniprot_position': 'aa_pos', 'AA_alt': 'aa_alt'})
misfit_ht = misfit_ht.drop('filename')
# Out:
# 2025-04-25 13:30:31.426 Hail: INFO: Reading table without type imputation
#   Loading field 'Uniprot_position' as type int32 (user-supplied)
#   Loading field 'AA_alt' as type str (user-supplied)
#   Loading field 'MisFit_D' as type float64 (user-supplied)
#   Loading field 'MisFit_S' as type float64 (user-supplied)

# %%
mf_mapping = mf_mapping.key_by('UniprotID')
misfit_ht = misfit_ht.annotate(
    enst = mf_mapping[misfit_ht.uniprot_id].TranscriptID, 
    ensg = mf_mapping[misfit_ht.uniprot_id].GeneID, 
    ensp = mf_mapping[misfit_ht.uniprot_id].ProteinID, 
    gene_symbol = mf_mapping[misfit_ht.uniprot_id].Symbol
)
misfit_ht.write('gs://genetics-gym-not-public/Trisha/updated_data_tables/misfit_scores.ht', True)
# Out:
# 2025-04-25 13:32:33.579 Hail: INFO: Coerced sorted dataset==(18708 + 2) / 18708]
# 2025-04-25 13:32:34.362 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2025-04-25 13:32:39.522 Hail: INFO: wrote table with 18708 rows in 1 partition to /tmp/__iruid_746-gQ8Fd2E2HsUX7bNj8KMzuF
# 2025-04-25 13:34:10.958 Hail: INFO: Coerced sorted dataset==(18708 + 1) / 18708]
# 2025-04-25 13:34:11.767 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2025-04-25 13:34:16.022 Hail: INFO: wrote table with 18708 rows in 1 partition to /tmp/__iruid_787-OkkzDAsB7hGlNQ5oHVglNz
# 2025-04-25 13:35:51.016 Hail: INFO: Coerced sorted dataset=>(18707 + 3) / 18708]
# 2025-04-25 13:35:51.839 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2025-04-25 13:35:56.119 Hail: INFO: wrote table with 18708 rows in 1 partition to /tmp/__iruid_828-YDMr4tTlvApChUXb8SEHmZ
# 2025-04-25 13:37:37.706 Hail: INFO: Coerced sorted dataset=>(18707 + 2) / 18708]
# ...

# %%
misfit_ht = hl.read_table('gs://genetics-gym-not-public/Trisha/updated_data_tables/misfit_scores.ht')
# Out:
# [Stage 6:=============(1024 + 1) / 1024][Stage 7:===============(796 + 1) / 796]

# %%
misfit_ht.show()
# Out:
# +--------+--------+----------+----------+--------------+-------------------+
# | aa_pos | aa_alt | MisFit_D | MisFit_S | uniprot_id   | enst              |
# +--------+--------+----------+----------+--------------+-------------------+
# |  int32 | str    |  float64 |  float64 | str          | str               |
# +--------+--------+----------+----------+--------------+-------------------+
# |      1 | "A"    | 7.35e-01 |       NA | "A0A024RBG1" | "ENST00000322209" |
# |      1 | "C"    | 1.00e+00 |       NA | "A0A024RBG1" | "ENST00000322209" |
# |      1 | "D"    | 9.46e-01 |       NA | "A0A024RBG1" | "ENST00000322209" |
# |      1 | "E"    | 8.12e-01 |       NA | "A0A024RBG1" | "ENST00000322209" |
# |      1 | "F"    | 7.10e-01 |       NA | "A0A024RBG1" | "ENST00000322209" |
# |      1 | "G"    | 7.26e-01 |       NA | "A0A024RBG1" | "ENST00000322209" |
# |      1 | "H"    | 9.84e-01 |       NA | "A0A024RBG1" | "ENST00000322209" |
# ...

# %% [markdown]
# ## Popeve

# %%
popeve_one = hl.import_table('gs://missense-scoring/popEVE_ukbb_20250312/NP_000005.3.csv', 
                            delimiter=',')
# Out:
# Initializing Hail with default parameters...
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# SPARKMONITOR_LISTENER: Started SparkListener for Jupyter Notebook
# SPARKMONITOR_LISTENER: Port obtained from environment: 51945
# SPARKMONITOR_LISTENER: Application Started: application_1745418617898_0001 ...Start Time: 1745421126695
# Running on Apache Spark version 3.5.0
# SparkUI available at http://tk-m.c.nnf-karczewski.internal:34405
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.133-4c60fddb171a
# LOGGING: writing to /home/hail/hail-20250423-1512-0.2.133-4c60fddb171a.log
# 2025-04-23 15:12:27.281 Hail: INFO: Reading table without type imputation1) / 1]
#   Loading field 'mutant' as type str (not specified)
#   Loading field 'gap frequency' as type str (not specified)
#   Loading field 'popEVE' as type str (not specified)
# ...

# %%
popeve_one.show()
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# +--------+---------------+----------+------------+---------------+----------+
# | mutant | gap frequency | popEVE   | popped EVE | popped ESM-1v | EVE      |
# +--------+---------------+----------+------------+---------------+----------+
# | str    | str           | str      | str        | str           | str      |
# +--------+---------------+----------+------------+---------------+----------+
# | "M1A"  | "0.846"       | "-4.48"  | "-4.713"   | "-4.247"      | "13.184" |
# | "M1C"  | "0.846"       | "-4.568" | "-4.696"   | "-4.441"      | "13.087" |
# | "M1D"  | "0.846"       | "-4.498" | "-4.541"   | "-4.454"      | "12.178" |
# | "M1E"  | "0.846"       | "-4.451" | "-4.523"   | "-4.379"      | "12.072" |
# | "M1F"  | "0.846"       | "-4.462" | "-4.555"   | "-4.368"      | "12.262" |
# | "M1G"  | "0.846"       | "-4.393" | "-4.497"   | "-4.29"       | "11.922" |
# ...

# %%
popeve_one.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'mutant': str
#     'gap frequency': str
#     'popEVE': str
#     'popped EVE': str
#     'popped ESM-1v': str
#     'EVE': str
#     'ESM-1v': str
# ----------------------------------------
# Key: []
# ----------------------------------------

# %%
popeve_raw_ht = hl.import_table(
        'gs://missense-scoring/popEVE_ukbb_20250312/*.csv',
        delimiter=',',
        source_file_field='filename',
        types = {
            'popEVE':hl.tfloat,
            'popped EVE':hl.tfloat,
            'popped ESM-1v':hl.tfloat,
            'EVE':hl.tfloat,
            'ESM-1v':hl.tfloat,
            
        },
        force=True,
        missing='',
    )
# Out:
# 2025-04-23 15:38:50.114 Hail: INFO: Reading table without type imputation1) / 1]
#   Loading field 'mutant' as type str (not specified)
#   Loading field 'gap frequency' as type str (not specified)
#   Loading field 'popEVE' as type float64 (user-supplied)
#   Loading field 'popped EVE' as type float64 (user-supplied)
#   Loading field 'popped ESM-1v' as type float64 (user-supplied)
#   Loading field 'EVE' as type float64 (user-supplied)
#   Loading field 'ESM-1v' as type float64 (user-supplied)

# %%
popeve_raw_ht.show()
# Out:
# +--------+---------------+-----------+------------+---------------+----------+
# | mutant | gap frequency |    popEVE | popped EVE | popped ESM-1v |      EVE |
# +--------+---------------+-----------+------------+---------------+----------+
# | str    | str           |   float64 |    float64 |       float64 |  float64 |
# +--------+---------------+-----------+------------+---------------+----------+
# | "M1A"  | "0.846"       | -4.48e+00 |  -4.71e+00 |     -4.25e+00 | 1.32e+01 |
# | "M1C"  | "0.846"       | -4.57e+00 |  -4.70e+00 |     -4.44e+00 | 1.31e+01 |
# | "M1D"  | "0.846"       | -4.50e+00 |  -4.54e+00 |     -4.45e+00 | 1.22e+01 |
# | "M1E"  | "0.846"       | -4.45e+00 |  -4.52e+00 |     -4.38e+00 | 1.21e+01 |
# | "M1F"  | "0.846"       | -4.46e+00 |  -4.56e+00 |     -4.37e+00 | 1.23e+01 |
# | "M1G"  | "0.846"       | -4.39e+00 |  -4.50e+00 |     -4.29e+00 | 1.19e+01 |
# | "M1H"  | "0.846"       | -4.43e+00 |  -4.43e+00 |     -4.43e+00 | 1.15e+01 |
# ...

# %%
popeve_ht = popeve_raw_ht.select(
    aa_pos = hl.int(popeve_raw_ht.mutant[1:-1]),
    aa_ref = popeve_raw_ht.mutant[0],
    aa_alt = popeve_raw_ht.mutant[-1],
    popEVE = popeve_raw_ht['popEVE'], 
    popped_EVE = popeve_raw_ht['popped EVE'], 
    popped_ESM_1v = popeve_raw_ht['popped ESM-1v'], 
    EVE = popeve_raw_ht['EVE'], 
    ESM_1v = popeve_raw_ht['ESM-1v'], 
    NP = popeve_raw_ht.filename.split('/')[-1][:-4]
    )

# %%
popeve_ht.show()
# Out:
# +--------+--------+--------+-----------+------------+---------------+----------+
# | aa_pos | aa_ref | aa_alt |    popEVE | popped_EVE | popped_ESM_1v |      EVE |
# +--------+--------+--------+-----------+------------+---------------+----------+
# |  int32 | str    | str    |   float64 |    float64 |       float64 |  float64 |
# +--------+--------+--------+-----------+------------+---------------+----------+
# |      1 | "M"    | "A"    | -4.48e+00 |  -4.71e+00 |     -4.25e+00 | 1.32e+01 |
# |      1 | "M"    | "C"    | -4.57e+00 |  -4.70e+00 |     -4.44e+00 | 1.31e+01 |
# |      1 | "M"    | "D"    | -4.50e+00 |  -4.54e+00 |     -4.45e+00 | 1.22e+01 |
# |      1 | "M"    | "E"    | -4.45e+00 |  -4.52e+00 |     -4.38e+00 | 1.21e+01 |
# |      1 | "M"    | "F"    | -4.46e+00 |  -4.56e+00 |     -4.37e+00 | 1.23e+01 |
# |      1 | "M"    | "G"    | -4.39e+00 |  -4.50e+00 |     -4.29e+00 | 1.19e+01 |
# |      1 | "M"    | "H"    | -4.43e+00 |  -4.43e+00 |     -4.43e+00 | 1.15e+01 |
# ...

# %%
popeve_ht.write('gs://missense-scoring/popeve_2025.ht')
# Out:
# 2025-04-23 15:50:55.774 Hail: INFO: wrote table with 184997718 rows in 18313 partitions to gs://missense-scoring/popeve_2025.ht
# [Stage 2:===================================================(18313 + 1) / 18313]

# %%
popeve_ht.write('gs://genetics-gym-not-public/Trisha/updated_data_tables/popeve_2025.ht')

# %%
p = hl.read_table('gs://genetics-gym-not-public/Trisha/updated_data_tables/popeve_2025.ht')
p.show()
# Out:
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 p = hl.read_table('gs://genetics-gym-not-public/Trisha/updated_data_tables/popeve_2025.ht')
#       2 p.show()
#
# File <decorator-gen-1686>:2, in read_table(path, _intervals, _filter_intervals, _n_partitions, _assert_type, _load_refs, _create_row_uids)
#
# File /opt/conda/miniconda3/lib/python3.11/site-packages/hail/typecheck/check.py:585, in _make_dec.<locals>.wrapper(__original_func, *args, **kwargs)
#     582 @decorator
#     583 def wrapper(__original_func: Callable[..., T], *args, **kwargs) -> T:
#     584     args_, kwargs_ = check_all(__original_func, args, kwargs, checkers, is_method=is_method)
# --> 585     return __original_func(*args_, **kwargs_)
#
# ...

# %% [markdown]
# ## MPC

# %%
# keyed by locus, allele
# mpc_ht = hl.read_table('gs://missense-scoring/mpc_grch38_deduped_with_outliers_2024-04-30.ht')

# %% [markdown]
# ## RASP

# %%
# keeyed by uniprot_id, uniprot_aa_pos, uniprot_aa_ref, uniprot_aa_alt
# rasp_ht = hl.read_table('gs://missense-scoring/mutation/rasp_scores.ht')

# %% [markdown]
# # Join tables

# %%
# assumes that mapping_id col names are specific
vsm_ens = {
    'esm1b': {'path': 'gs://genetics-gym-not-public/Trisha/updated_data_tables/esm1b_scores.ht', 
              'score_cols': ['esm_score']
             },
    'misfit': {'path': 'gs://genetics-gym-not-public/Trisha/updated_data_tables/misfit_scores.ht', 
               'score_cols': ['MisFit_D', 'MisFit_S']
              },
    'AM': {'path': 'gs://genetics-gym-not-public/Trisha/hail_VSM_tables_updated/AM.ht', 
           'score_cols': ['AM_score']
           }, 
    'RASP': {'path': 'gs://missense-scoring/mutation/rasp_scores.ht', 
             'score_cols': ['rasp_score']
            },
    'MPC': {'path': 'gs://missense-scoring/mpc_grch38_deduped_with_outliers_2024-04-30.ht', 
             'score_cols': ['mpc']
            },
    
}

vsm_rs = {
    'popeve': {'path': 'gs://genetics-gym-not-public/Trisha/updated_data_tables/popeve_2025.ht',  
               'score_cols': ['popEVE', 'EVE', 'ESM_1v']}
}


higher_is_less_deleterious = {
    'esm_score':True,
    'proteinmpnn_llr':True,
    'AM_score':False,
    'score_PAI3D':False,
    'rasp_score':False,
    'misfit': False,
    'MisFit_S':False,
    'misfit':False,
    'popeve':True,
    'eve':False,
    'esm1_v':True,
    'mpc':False,
}

# %%
vsm_ht = hl.read_table('gs://genetics-gym-not-public/Trisha/linker_ens_iso_all_mapped.ht')

## Uniprot keys
# esm1b
ht = hl.read_table(vsm_ens['esm1b']['path'])
ht = ht.key_by('uniprot_isoform', 'aa_pos', 'aa_ref', 'aa_alt')
vsm_ht = vsm_ht.annotate(
    esm1b = ht[vsm_ht.uniprot_merged, vsm_ht.aa_pos, vsm_ht.aa_ref, vsm_ht.aa_alt].esm_score
)

# RASP
ht = hl.read_table(vsm_ens['RASP']['path'])
ht = ht.rename({'uniprot_aa_pos': 'aa_pos', 'uniprot_aa_ref': 'aa_ref', 'uniprot_aa_alt': 'aa_alt'})
ht = ht.key_by('uniprot_id', 'aa_pos', 'aa_ref', 'aa_alt')
joined = ht[vsm_ht.uniprot_merged, vsm_ht.aa_pos, vsm_ht.aa_ref, vsm_ht.aa_alt]
vsm_ht = vsm_ht.annotate(
    rasp_score = joined.rasp_score, 
    
)

## ENST keys
# misfit
ht = hl.read_table(vsm_ens['misfit']['path'])
ht = ht.key_by('enst', 'aa_pos', 'aa_alt')
joined = ht[vsm_ht.enst, vsm_ht.aa_pos, vsm_ht.aa_ref, vsm_ht.aa_alt]
vsm_ht = vsm_ht.annotate(
    MisFit_S = joined.MisFit_S, 
    MisFit_D = joined.MisFit_D
    
)

## Locus, allele keys
# AM
ht = hl.read_table(vsm_ens['AM']['path'])
ht = ht.key_by('locus', 'alleles')
vsm_ht = vsm_ht.annotate(
    AM = ht[vsm_ht.locus, vsm_ht.alleles].AM_score, 
)

# MPC
ht = hl.read_table(vsm_ens['AM']['path'])
ht = ht.key_by('locus', 'alleles')
vsm_ht = vsm_ht.annotate(
    mpc = ht[vsm_ht.locus, vsm_ht.alleles].mpc, 
)

# %%
vsm_ht.write('gs://genetics-gym-not-public/Trisha/updated_data_tables/new_vsm_1.ht', overwrite=True)
# Out:
# 2025-04-25 15:45:24.015 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2025-04-25 15:46:54.774 Hail: INFO: Coerced sorted dataset==(42286 + 2) / 42286]
# 2025-04-25 15:46:55.733 Hail: INFO: Coerced dataset with out-of-order partitions.
# Exception in thread "Thread-40" java.lang.NullPointerExceptionge 2:(14909 + 12) / 14909]
# 	at sparkmonitor.listener.JupyterSparkMonitorListener$TaskUpdaterThread.$anonfun$run$1(CustomListener.scala:116)
# 	at scala.collection.TraversableLike$grouper$1$.apply(TraversableLike.scala:465)
# 	at scala.collection.TraversableLike$grouper$1$.apply(TraversableLike.scala:455)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at scala.collection.TraversableLike.groupBy(TraversableLike.scala:524)
# ...

# %%
vsm_ht = hl.read_table('gs://genetics-gym-not-public/Trisha/updated_data_tables/new_vsm_1.ht')
vsm_ht.show()
# Out:
# [Stage 0:>                                                          (0 + 4) / 4]
# +---------------+------------+--------+--------+--------+-------------+
# | locus         | alleles    | aa_pos | aa_ref | aa_alt | gene_symbol |
# +---------------+------------+--------+--------+--------+-------------+
# | locus<GRCh38> | array<str> |  int32 | str    | str    | str         |
# +---------------+------------+--------+--------+--------+-------------+
# | chr1:65568    | ["A","C"]  |      2 | "K"    | "Q"    | "OR4F5"     |
# | chr1:65568    | ["A","G"]  |      2 | "K"    | "E"    | "OR4F5"     |
# | chr1:65569    | ["A","C"]  |      2 | "K"    | "T"    | "OR4F5"     |
# | chr1:65569    | ["A","G"]  |      2 | "K"    | "R"    | "OR4F5"     |
# | chr1:65569    | ["A","T"]  |      2 | "K"    | "M"    | "OR4F5"     |
# | chr1:65570    | ["G","C"]  |      2 | "K"    | "N"    | "OR4F5"     |
# | chr1:65570    | ["G","T"]  |      2 | "K"    | "N"    | "OR4F5"     |
# ...

# %%
vsm_ht_f = vsm_ht.filter(vsm_ht.uniprot_merged == 'A0A024RBG1')
vsm_ht_f.show()
# Out:
# [Stage 6:=============(1024 + 1) / 1024][Stage 7:==============(796 + 16) / 796]
# +----------------+------------+--------+--------+--------+-------------+
# | locus          | alleles    | aa_pos | aa_ref | aa_alt | gene_symbol |
# +----------------+------------+--------+--------+--------+-------------+
# | locus<GRCh38>  | array<str> |  int32 | str    | str    | str         |
# +----------------+------------+--------+--------+--------+-------------+
# | chr1:148748956 | ["A","C"]  |      2 | "M"    | "L"    | "NUDT4B"    |
# | chr1:148748956 | ["A","G"]  |      2 | "M"    | "V"    | "NUDT4B"    |
# | chr1:148748956 | ["A","T"]  |      2 | "M"    | "L"    | "NUDT4B"    |
# | chr1:148748957 | ["T","A"]  |      2 | "M"    | "K"    | "NUDT4B"    |
# | chr1:148748957 | ["T","C"]  |      2 | "M"    | "T"    | "NUDT4B"    |
# | chr1:148748957 | ["T","G"]  |      2 | "M"    | "R"    | "NUDT4B"    |
# | chr1:148748958 | ["G","A"]  |      2 | "M"    | "I"    | "NUDT4B"    |
# ...

# %%
vsm_ht_f.show(100)
# Out:
# +----------------+------------+--------+--------+--------+-------------+
# | locus          | alleles    | aa_pos | aa_ref | aa_alt | gene_symbol |
# +----------------+------------+--------+--------+--------+-------------+
# | locus<GRCh38>  | array<str> |  int32 | str    | str    | str         |
# +----------------+------------+--------+--------+--------+-------------+
# | chr1:148748956 | ["A","C"]  |      2 | "M"    | "L"    | "NUDT4B"    |
# | chr1:148748956 | ["A","G"]  |      2 | "M"    | "V"    | "NUDT4B"    |
# | chr1:148748956 | ["A","T"]  |      2 | "M"    | "L"    | "NUDT4B"    |
# | chr1:148748957 | ["T","A"]  |      2 | "M"    | "K"    | "NUDT4B"    |
# | chr1:148748957 | ["T","C"]  |      2 | "M"    | "T"    | "NUDT4B"    |
# | chr1:148748957 | ["T","G"]  |      2 | "M"    | "R"    | "NUDT4B"    |
# | chr1:148748958 | ["G","A"]  |      2 | "M"    | "I"    | "NUDT4B"    |
# | chr1:148748958 | ["G","C"]  |      2 | "M"    | "I"    | "NUDT4B"    |
# ...

# %%
vsm_ht_f2 = vsm_ht_f.filter((vsm_ht_f.aa_pos == 2) & 
                           (vsm_ht_f.aa_alt == 'L') & 
                           (vsm_ht_f.enst == 'ENST00000322209'))
vsm_ht_f2.show()
# Out:
# [Stage 6:(1024 + 1) / 1024][Stage 7:=(796 + 1) / 796][Stage 14:(1024 + 1) / 1024]
# +----------------+------------+--------+--------+--------+-------------+
# | locus          | alleles    | aa_pos | aa_ref | aa_alt | gene_symbol |
# +----------------+------------+--------+--------+--------+-------------+
# | locus<GRCh38>  | array<str> |  int32 | str    | str    | str         |
# +----------------+------------+--------+--------+--------+-------------+
# | chr1:148748956 | ["A","C"]  |      2 | "M"    | "L"    | "NUDT4B"    |
# | chr1:148748956 | ["A","T"]  |      2 | "M"    | "L"    | "NUDT4B"    |
# +----------------+------------+--------+--------+--------+-------------+
#
# +-----------------+-------------------+-------------------+-------------------+
# | uniprot_isoform | enst              | ensp              | ensg              |
# +-----------------+-------------------+-------------------+-------------------+
# ...

# %%
misfit_f = misfit_ht.filter((misfit_ht.enst == 'ENST00000322209') &
                            (misfit_ht.aa_pos == 2) & 
                            (misfit_ht.aa_alt == 'L' ))
misfit_f.show()
# Out:
# Exception in thread "Thread-40" java.lang.NullPointerException:(1024 + 1) / 1024]
# 	at sparkmonitor.listener.JupyterSparkMonitorListener$TaskUpdaterThread.$anonfun$run$1(CustomListener.scala:116)
# 	at scala.collection.TraversableLike$grouper$1$.apply(TraversableLike.scala:465)
# 	at scala.collection.TraversableLike$grouper$1$.apply(TraversableLike.scala:455)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at scala.collection.TraversableLike.groupBy(TraversableLike.scala:524)
# 	at scala.collection.TraversableLike.groupBy$(TraversableLike.scala:454)
# 	at scala.collection.AbstractTraversable.groupBy(Traversable.scala:108)
# 	at sparkmonitor.listener.JupyterSparkMonitorListener$TaskUpdaterThread.run(CustomListener.scala:116)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# ...
